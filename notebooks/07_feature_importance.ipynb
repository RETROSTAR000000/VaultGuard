# %% [markdown]
# # VaultGuard permutation feature importance
# This notebook produces the feature-importance CSV and chart shown in the Streamlit Model Information page.

# %%
from src.feature_importance import create_feature_importance
importance_df = create_feature_importance()
importance_df.head(10)
